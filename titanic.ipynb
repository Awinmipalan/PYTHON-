# %%
import numpy as np

# %%
import pandas as pd
# Out:
# C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:print(os.path.join(dirname,filename))

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dat = pd.read_csv('C:\\Users\\DELL\\Downloads\\titanic.txt')

# %%
dat.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %%
dat.shape
# Out:
# (887, 8)

# %%
dat.describe()
# Out:
#          Survived      Pclass         Age  Siblings/Spouses Aboard  \
# count  887.000000  887.000000  887.000000               887.000000
# mean     0.385569    2.305524   29.471443                 0.525366
# std      0.487004    0.836662   14.121908                 1.104669
# min      0.000000    1.000000    0.420000                 0.000000
# 25%      0.000000    2.000000   20.250000                 0.000000
# 50%      0.000000    3.000000   28.000000                 0.000000
# 75%      1.000000    3.000000   38.000000                 1.000000
# max      1.000000    3.000000   80.000000                 8.000000
#
#        Parents/Children Aboard       Fare
# count               887.000000  887.00000
# mean                  0.383315   32.30542
# std                   0.807466   49.78204
# min                   0.000000    0.00000
# 25%                   0.000000    7.92500
# 50%                   0.000000   14.45420
# 75%                   0.000000   31.13750
# ...

# %%
dat['Age'].median()
# Out:
# 28.0

# %%
dat['Sex'].value_counts().plot(kind="pie",)
plt.show()

# %%
plt.hist(dat['Age'], bins=5)
plt.show()

# %%
sns.distplot(dat['Age'])
plt.show
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6488\2025056577.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dat['Age'])
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=dat['Pclass'],y=dat['Age'])
plt.show()

# %%
sns.scatterplot(y=dat['Siblings/Spouses Aboard'],x=dat['Age'],hue=dat["Sex"],)
plt.show()

# %%
sns.barplot(x=dat['Pclass'],y=dat['Age'],hue=dat["Sex"])
plt.show()

# %%
sns.scatterplot(x=dat['Pclass'],y=dat['Age'],jitter=True)
plt.show()

# %%
sns.boxplot(x=dat['Survived'],y=dat['Age'],hue=dat["Sex"])
plt.show()

# %%
sns.distplot(dat[dat['Survived']==0]['Age'], hist=False, color="blue")
sns.distplot(dat[dat['Survived']==1]['Age'], hist=False, color="orange")
plt.show
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6488\175863322.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dat[dat['Survived']==0]['Age'], hist=False, color="blue")
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6488\175863322.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# ...

# %%
pd.crosstab(dat['Pclass'],dat['Survived'])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         368  119

# %%
sns.heatmap(pd.crosstab(dat['Pclass'],dat['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
sns.clustermap(pd.crosstab(dat['Age'],dat['Survived']))

# %%
dat['Fare'].plot(kind='box')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(x=dat['Survived'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ml=dat[(dat."Sex"='male')]
# Out:
#   Cell In[174], line 1
#     ml=dat[(dat."Sex"='male')]
#                 ^
# SyntaxError: invalid syntax
